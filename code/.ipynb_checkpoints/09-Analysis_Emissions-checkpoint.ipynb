# %% [markdown]
# # Emisiones por Industria: Análisis y visualización del dato

# %% [markdown]
# #### Importando las librerias necesarias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# #### Leyendo el fichero geolocalizado CSV del total de Emisiones de los años 2001 al 2015

# %%
FEmissions = pd.ExcelFile('../data/csv/Emissions/geo/Comp_by_Emi_total_Geo_2001-2015.xlsx', 
                       sheetname='Comp_by_Emi_total_Geo_2001-2015')
dfEmiByComplex = pd.read_excel(FEmissions,index_col=None,na_values=['NA'])

# %% [markdown]
# ### Análisis de datos

# %% [markdown]
# Vemos la forma del dataframe

# %%
dfEmiByComplex.shape
# Out:
# (60026, 23)

# %% [markdown]
# Mostramos los primeros registros

# %%
dfEmiByComplex.sample(5)
# Out:
#        CodigoPRTR                  NombreDelComplejo1  \
# 882           115  FUNDICIONES ESPECIALES ZAFRA,S.A.L
# 42335         592                              VERNIS
# 40276        5404                        CREMOVA S.L.
# 45395        6515               ENGIE CARTAGENA, S.L.
# 8187         1593                 UBE CHEMICAL EUROPE
#
#                             NombreDelComplejo2  \
# 882         FUNDICIONES ESPECIALES ZAFRA,S.A.L
# 42335                                   VERNIS
# 40276                                      NaN
# 45395                    ENGIE CARTAGENA, S.L.
# 8187   UBE CORPORATION EUROPE S.A. UNIPERSONAL
#
#                                  EmpresaMatriz  \
# 882        FUNDICIONES ESPECIALES ZAFRA,S.A.L.
# 42335                             VERNIS, S.A.
# 40276                                      NaN
# 45395                    ENGIE CARTAGENA, S.L.
# 8187   UBE CORPORATION EUROPE S.A. UNIPERSONAL
#
#                                       ActividadEconomica  AnyoReferencia  \
# 882                             FUNDICIÓN DE HIERRO GRIS            2009
# 42335         FABRICACIÓN DE FRITAS Y ESMALTES CERÁMICOS            2004
# 40276                                                NaN            2004
# 45395  GENERACIÓN DE ENERGÍA ELÉCTRICA POR C.C. DE GA...            2015
# 8187   FABRICACIÓN DE CAPROLACTAMA, 1,6 HEXANODIOL, S...            2005
#
#                                             Contaminante  \
# 882    Hidrocarburos aromáticos policíclicos totales ...
# 42335                      Óxidos de nitrógeno (NOx/NO2)
# 40276                                     Amoniaco (NH3)
# 45395                      Óxidos de nitrógeno (NOx/NO2)
# 8187                                      Amoniaco (NH3)
#
#        CantidadTotalkgporaAnyo MedioReceptor Metodo    ...    CodIPPC  \
# 882                      100.0          Aire      C    ...        2.4
# 42335                 161000.0          Aire      C    ...        3.3
# 40276                  12200.0          Aire      C    ...        NaN
# 45395                 110460.0          Aire      M    ...     1.1.b)
# 8187                  219000.0          Aire      C    ...     4.1.d)
#
#                              Direccion CodPostal    Poblacion  \
# 882       CTRA.BADAJOZ-GRANADA KM 74,6    6300.0        ZAFRA
# 42335                  MANUEL ESCOBEDO   12200.0         ONDA
# 40276                              NaN       NaN          NaN
# 45395           CTRA. NAL. 343, KM. 10   30350.0  ESCOMBRERAS
# 8187   POLIGONO INDUSTRIAL EL SERRALLO   12100.0          NaN
#
#                                         Municipio           Provincia  \
# 882                                         Zafra             Badajoz
# 42335                                        Onda  Castellón/Castelló
# 40276                                         NaN                 NaN
# 45395                                   Cartagena              Murcia
# 8187   Castellón de la Plana/Castelló de la Plana  Castellón/Castelló
#
#                         CCAA DemarcacionHidrografica    Latitud  Longitud
# 882             Extremadura                 Guadiana  38.421568 -6.409643
# 42335  Comunidad Valenciana                    Jucar  39.969658 -0.245385
# 40276                    NaN                     NaN        NaN       NaN
# 45395    Murcia (Región de)                   Segura  37.980974 -1.131455
# 8187   Comunidad Valenciana                    Jucar  39.986356 -0.051325
#
# [5 rows x 23 columns]

# %% [markdown]
# Chequeamos el tipo de dato

# %%
dfEmiByComplex.dtypes
# Out:
# CodigoPRTR                   int64
# NombreDelComplejo1          object
# NombreDelComplejo2          object
# EmpresaMatriz               object
# ActividadEconomica          object
# AnyoReferencia               int64
# Contaminante                object
# CantidadTotalkgporaAnyo    float64
# MedioReceptor               object
# Metodo                      object
# Metodo_MCE                  object
# CNAE-2009                  float64
# CodPRTRDEI                  object
# CodIPPC                     object
# Direccion                   object
# CodPostal                  float64
# Poblacion                   object
# Municipio                   object
# Provincia                   object
# CCAA                        object
# DemarcacionHidrografica     object
# Latitud                    float64
# Longitud                   float64
# dtype: object

# %% [markdown]
# Reducimos el dataframe a las principales columnas, ya que todas no nos interesan...

# %%
dfEmiByComplexRedu = dfEmiByComplex.iloc[:,[0,3,4,5,6,7,8,14,15,16,17,18,19,21,22]]
dfEmiByComplexRedu.head(3)
# Out:
#    CodigoPRTR                        EmpresaMatriz  \
# 0         100  GRANJA AVÍCOLA HUEVOS CABAÑAS, S.L.
# 1         100  GRANJA AVÍCOLA HUEVOS CABAÑAS, S.L.
# 2         100  GRANJA AVÍCOLA HUEVOS CABAÑAS, S.L.
#
#                           ActividadEconomica  AnyoReferencia    Contaminante  \
# 0  EXPLOTACIÓN AVÍCOLA, PRODUCCIÓN DE HUEVOS            2014  Amoniaco (NH3)
# 1  EXPLOTACIÓN AVÍCOLA, PRODUCCIÓN DE HUEVOS            2008  Amoniaco (NH3)
# 2  EXPLOTACIÓN AVÍCOLA, PRODUCCIÓN DE HUEVOS            2012  Amoniaco (NH3)
#
#    CantidadTotalkgporaAnyo MedioReceptor  \
# 0                 26165.98          Aire
# 1                 39200.00          Aire
# 2                 15600.00          Aire
#
#                                      Direccion  CodPostal           Poblacion  \
# 0  CTRA. ZAFRA, S/N POLÍGONO 25, PARCELA 90001     6360.0  FUENTE DEL MAESTRE
# 1  CTRA. ZAFRA, S/N POLÍGONO 25, PARCELA 90001     6360.0  FUENTE DEL MAESTRE
# 2  CTRA. ZAFRA, S/N POLÍGONO 25, PARCELA 90001     6360.0  FUENTE DEL MAESTRE
#
#             Municipio Provincia          CCAA    Latitud  Longitud
# 0  Fuente del Maestre   Badajoz  Extremadura   38.526727 -6.449011
# 1  Fuente del Maestre   Badajoz  Extremadura   38.526727 -6.449011
# 2  Fuente del Maestre   Badajoz  Extremadura   38.526727 -6.449011

# %% [markdown]
# Renombramos las columnas Año y Cantidad en peso del contaminante

# %%
dfEmiByComplexRedu.rename(columns={'CantidadTotalkgporaAnyo': 'Total_Kg'}, inplace=True)
dfEmiByComplexRedu.rename(columns={'AnyoReferencia': 'Year'}, inplace=True)
# Out:
# C:\Users\julia\Anaconda3\lib\site-packages\pandas\core\frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %% [markdown]
# Seleccionamos las variables tipo "object" dentro del dataframe

# %%
obj_dfEmiByComplexRedu = dfEmiByComplexRedu.select_dtypes(include=['object']).copy()
obj_dfEmiByComplexRedu.head(3)
# Out:
#                          EmpresaMatriz  \
# 0  GRANJA AVÍCOLA HUEVOS CABAÑAS, S.L.
# 1  GRANJA AVÍCOLA HUEVOS CABAÑAS, S.L.
# 2  GRANJA AVÍCOLA HUEVOS CABAÑAS, S.L.
#
#                           ActividadEconomica    Contaminante MedioReceptor  \
# 0  EXPLOTACIÓN AVÍCOLA, PRODUCCIÓN DE HUEVOS  Amoniaco (NH3)          Aire
# 1  EXPLOTACIÓN AVÍCOLA, PRODUCCIÓN DE HUEVOS  Amoniaco (NH3)          Aire
# 2  EXPLOTACIÓN AVÍCOLA, PRODUCCIÓN DE HUEVOS  Amoniaco (NH3)          Aire
#
#                                      Direccion           Poblacion  \
# 0  CTRA. ZAFRA, S/N POLÍGONO 25, PARCELA 90001  FUENTE DEL MAESTRE
# 1  CTRA. ZAFRA, S/N POLÍGONO 25, PARCELA 90001  FUENTE DEL MAESTRE
# 2  CTRA. ZAFRA, S/N POLÍGONO 25, PARCELA 90001  FUENTE DEL MAESTRE
#
#             Municipio Provincia          CCAA
# 0  Fuente del Maestre   Badajoz  Extremadura
# 1  Fuente del Maestre   Badajoz  Extremadura
# 2  Fuente del Maestre   Badajoz  Extremadura

# %% [markdown]
# Contabilizamos las emisiones por el "Medio Receptor"

# %%
dfEmiByComplexRedu["MedioReceptor"].value_counts()
# Out:
# Aire                                                                44811
# Litoral                                                              5705
# EDAR de titularidad pública (municipal o autonómica)                 1967
# Cuenca intercomunitaria de titularidad estatal                       1942
# Cuenca intracomunitaria de titularidad autonómica                    1522
# Red de alcantarillado                                                1453
# EPER Cuenca Intercomunitaria                                          713
# Cuenca intracomunitaria                                               392
# Depuradora privada externa al complejo industrial                     366
# Red de alcantarillado sin depuración (municipales o autonómicos)      360
# cuenca intercomunitaria gestionada por comunidad autonoma             349
# EPER Depuradora                                                       310
# Cuenca intracomunitaria de titularidad estatal                        136
# Name: MedioReceptor, dtype: int64

# %% [markdown]
# Generamos una tabla de frecuencias relativas de eventos de Emisiones al Medio receptor, vemos que "Aire" es el más frecuente

# %%
# El Medio "Aire" es el más frecuente
100 * dfEmiByComplexRedu["MedioReceptor"].value_counts() / len(dfEmiByComplexRedu["MedioReceptor"])
# Out:
# Aire                                                                74.652651
# Litoral                                                              9.504215
# EDAR de titularidad pública (municipal o autonómica)                 3.276913
# Cuenca intercomunitaria de titularidad estatal                       3.235265
# Cuenca intracomunitaria de titularidad autonómica                    2.535568
# Red de alcantarillado                                                2.420618
# EPER Cuenca Intercomunitaria                                         1.187819
# Cuenca intracomunitaria                                              0.653050
# Depuradora privada externa al complejo industrial                    0.609736
# Red de alcantarillado sin depuración (municipales o autonómicos)     0.599740
# cuenca intercomunitaria gestionada por comunidad autonoma            0.581415
# EPER Depuradora                                                      0.516443
# Cuenca intracomunitaria de titularidad estatal                       0.226568
# Name: MedioReceptor, dtype: float64

# %% [markdown]
# Filtramos sólo por el valor "Aire", ya que sólo nos interesan las Emisiones a este medio por ser el objeto de este estudio

# %%
dfEmiByComplexReduAir = dfEmiByComplexRedu[dfEmiByComplexRedu['MedioReceptor'].str.contains("Aire", case=False)]

# %% [markdown]
# #### Agrupamos los valores por Año emisión y Tipo de Contaminante, visualizando los totales por Kiogramos emitidos

# %%
dfEmiByComplexReduAir.groupby(['Year', 'Contaminante'])[['Total_Kg']].sum().sort_values(by='Total_Kg', ascending=False)
# Out:
#                                                       Total_Kg
# Year Contaminante
# 2006 Dióxido de carbono (CO2)                     1.637990e+11
# 2004 Dióxido de carbono (CO2)                     1.608950e+11
# 2007 Dióxido de carbono (CO2)                     1.584977e+11
# 2001 Dióxido de carbono (CO2)                     1.574937e+11
# 2005 Dióxido de carbono (CO2)                     1.553950e+11
# 2008 Dióxido de carbono (CO2)                     1.485147e+11
# 2012 Dióxido de carbono (CO2)                     1.333670e+11
# 2009 Dióxido de carbono (CO2)                     1.241286e+11
# 2011 Dióxido de carbono (CO2)                     1.207911e+11
# 2002 Dióxido de carbono (CO2)                     1.198040e+11
# 2015 Dióxido de carbono (CO2)                     1.188088e+11
# 2003 Dióxido de carbono (CO2)                     1.187660e+11
# 2010 Dióxido de carbono (CO2)                     1.127622e+11
# 2014 Dióxido de carbono (CO2)                     1.082787e+11
# 2013 Dióxido de carbono (CO2)                     1.048104e+11
# 2001 Óxidos de azufre (SOx/SO2)                   1.201767e+09
# 2002 Óxidos de azufre (SOx/SO2)                   1.171332e+09
# 2004 Óxidos de azufre (SOx/SO2)                   1.113712e+09
# 2003 Óxidos de azufre (SOx/SO2)                   9.899350e+08
# 2006 Óxidos de azufre (SOx/SO2)                   9.867650e+08
# 2007 Óxidos de azufre (SOx/SO2)                   9.662760e+08
# 2005 Óxidos de azufre (SOx/SO2)                   8.737260e+08
# 2007 Óxidos de nitrógeno (NOx/NO2)                5.201890e+08
# 2004 Óxidos de nitrógeno (NOx/NO2)                4.915630e+08
# 2006 Óxidos de nitrógeno (NOx/NO2)                4.610050e+08
# 2005 Óxidos de nitrógeno (NOx/NO2)                4.531280e+08
# 2001 Óxidos de nitrógeno (NOx/NO2)                4.489935e+08
# 2002 Óxidos de nitrógeno (NOx/NO2)                4.466870e+08
# 2003 Óxidos de nitrógeno (NOx/NO2)                4.228560e+08
# 2008 Óxidos de nitrógeno (NOx/NO2)                3.870788e+08
# ...                                                        ...
# 2002 Hexaclorobenceno (HCB)                       3.440000e+01
# 2012 Pentaclorofenol (PCP)                        2.857000e+01
# 2007 Policlorobifenilos (PCB)                     2.594000e+01
# 2008 Hexaclorobenceno (HCB)                       2.210000e+01
#      Triclorobencenos totales (TCB)               2.210000e+01
# 2012 Policlorobifenilos (PCB)                     1.731000e+01
# 2006 PCDD + PCDF (dioxinas + furanos) (como Teq)  1.616729e+01
# 2004 Triclorobencenos totales (TCB)               1.460000e+01
#      Hexaclorobenceno (HCB)                       1.460000e+01
# 2008 Policlorobifenilos (PCB)                     1.326500e+01
# 2006 Pentaclorofenol (PCP)                        1.200000e+01
# 2014 Policlorobifenilos (PCB)                     1.090200e+01
# 2015 Policlorobifenilos (PCB)                     9.764000e+00
# 2012 Clorofluorocarburos (CFC)                    4.940000e+00
# 2015 Clorofluorocarburos (CFC)                    3.065000e+00
# 2014 Clorofluorocarburos (CFC)                    2.500000e+00
# 2010 PCDD + PCDF (dioxinas + furanos) (como Teq)  4.941766e-01
# 2002 PCDD + PCDF (dioxinas + furanos) (como Teq)  1.772100e-01
# 2003 PCDD + PCDF (dioxinas + furanos) (como Teq)  1.463000e-01
# 2001 PCDD + PCDF (dioxinas + furanos) (como Teq)  1.225300e-01
# 2014 PCDD + PCDF (dioxinas + furanos) (como Teq)  8.940747e-02
# 2013 PCDD + PCDF (dioxinas + furanos) (como Teq)  8.920830e-02
# 2004 PCDD + PCDF (dioxinas + furanos) (como Teq)  7.560000e-02
# 2011 PCDD + PCDF (dioxinas + furanos) (como Teq)  5.669255e-02
# 2009 PCDD + PCDF (dioxinas + furanos) (como Teq)  5.294599e-02
# 2008 PCDD + PCDF (dioxinas + furanos) (como Teq)  5.070059e-02
# 2007 PCDD + PCDF (dioxinas + furanos) (como Teq)  4.656800e-02
# 2005 PCDD + PCDF (dioxinas + furanos) (como Teq)  3.881000e-02
# 2015 PCDD + PCDF (dioxinas + furanos) (como Teq)  3.650504e-02
# 2012 PCDD + PCDF (dioxinas + furanos) (como Teq)  2.470192e-02
#
# [538 rows x 1 columns]

# %% [markdown]
# Contabilizamos los totales de Emisiones por tipos de Contaminantes para todos los años de emisiones

# %%
dfEmiByComplexReduAir["Contaminante"].value_counts()
# Out:
# Amoniaco (NH3)                                                            20003
# Óxidos de nitrógeno (NOx/NO2)                                              4302
# Dióxido de carbono (CO2)                                                   2627
# Metano (CH4)                                                               2244
# Óxidos de azufre (SOx/SO2)                                                 1888
# Partículas (PM10)                                                          1614
# Compuestos orgánicos volátiles distintos del metano (COVNM)                1349
# Níquel y compuestos (como Ni)                                              1252
# Flúor y compuestos inorgánicos (como HF)                                   1041
# Monóxido de carbono (CO)                                                    982
# Zinc y compuestos (como Zn)                                                 902
# Cloro y compuestos inorgánicos (como HCl)                                   741
# Óxido nitroso (N2O)                                                         738
# Plomo y compuestos (como Pb)                                                689
# Mercurio y compuestos (como Hg)                                             681
# Cadmio y compuestos (como Cd)                                               654
# Arsénico y compuestos (como As)                                             510
# Cromo y compuestos (como Cr)                                                449
# Benceno                                                                     388
# Cobre y compuestos (como Cu)                                                360
# Hidrocarburos aromáticos policíclicos totales PRTR (HAP totales PRTR)       353
# PCDD + PCDF (dioxinas + furanos) (como Teq)                                 221
# Hidrofluorocarburos (HFC)                                                   146
# Cianuro de hidrógeno (HCN)                                                  113
# Naftaleno                                                                    83
# Hidroclorofluorocarburos (HCFC)                                              79
# Ftalato de bis (2-etilhexilo) (DEHP)                                         73
# Diclorometano (DCM)                                                          72
# Perfluorocarburos (PFC)                                                      39
# Tetracloroetileno (PER)                                                      30
# Cloruro de vinilo                                                            28
# Policlorobifenilos (PCB)                                                     27
# Tricloroetileno                                                              21
# Tetraclorometano (TCM)                                                       19
# Triclorometano                                                               18
# Clorofluorocarburos (CFC)                                                    15
# 1,2-dicloroetano (DCE)                                                       12
# Hexaclorobenceno (HCB)                                                       11
# Antraceno                                                                    10
# Pentaclorofenol (PCP)                                                         7
# Triclorobencenos totales (TCB)                                                5
# 1,1,1-tricloroetano (TCE)                                                     4
# Óxido de etileno                                                              4
# Hexafluoruro de azufre (SF6)                                                  3
# 1,1,2,2-tetracloroetano                                                       3
# 1,2,3,4,5,6-hexaclorociclohexano (HCH)                                        1
# Name: Contaminante, dtype: int64

# %% [markdown]
# Generamos una tabla de frecuencias relativas de Contaminantes emitidos al Aire, el Amoniaco representa un porcentaje muy alto

# %%
# tabla de frecuencia relativa de Contaminantes emitidos al Aire,

100 * dfEmiByComplexReduAir["Contaminante"].value_counts() / len(dfEmiByComplexReduAir["Contaminante"])
# Out:
# Amoniaco (NH3)                                                            44.638593
# Óxidos de nitrógeno (NOx/NO2)                                              9.600321
# Dióxido de carbono (CO2)                                                   5.862400
# Metano (CH4)                                                               5.007699
# Óxidos de azufre (SOx/SO2)                                                 4.213251
# Partículas (PM10)                                                          3.601794
# Compuestos orgánicos volátiles distintos del metano (COVNM)                3.010422
# Níquel y compuestos (como Ni)                                              2.793957
# Flúor y compuestos inorgánicos (como HF)                                   2.323090
# Monóxido de carbono (CO)                                                   2.191426
# Zinc y compuestos (como Zn)                                                2.012899
# Cloro y compuestos inorgánicos (como HCl)                                  1.653612
# Óxido nitroso (N2O)                                                        1.646917
# Plomo y compuestos (como Pb)                                               1.537569
# Mercurio y compuestos (como Hg)                                            1.519716
# Cadmio y compuestos (como Cd)                                              1.459463
# Arsénico y compuestos (como As)                                            1.138113
# Cromo y compuestos (como Cr)                                               1.001986
# Benceno                                                                    0.865859
# Cobre y compuestos (como Cu)                                               0.803374
# Hidrocarburos aromáticos policíclicos totales PRTR (HAP totales PRTR)      0.787753
# PCDD + PCDF (dioxinas + furanos) (como Teq)                                0.493182
# Hidrofluorocarburos (HFC)                                                  0.325813
# Cianuro de hidrógeno (HCN)                                                 0.252170
# Naftaleno                                                                  0.185222
# Hidroclorofluorocarburos (HCFC)                                            0.176296
# Ftalato de bis (2-etilhexilo) (DEHP)                                       0.162906
# Diclorometano (DCM)                                                        0.160675
# Perfluorocarburos (PFC)                                                    0.087032
# Tetracloroetileno (PER)                                                    0.066948
# Cloruro de vinilo                                                          0.062485
# Policlorobifenilos (PCB)                                                   0.060253
# Tricloroetileno                                                            0.046863
# Tetraclorometano (TCM)                                                     0.042400
# Triclorometano                                                             0.040169
# Clorofluorocarburos (CFC)                                                  0.033474
# 1,2-dicloroetano (DCE)                                                     0.026779
# Hexaclorobenceno (HCB)                                                     0.024548
# Antraceno                                                                  0.022316
# Pentaclorofenol (PCP)                                                      0.015621
# Triclorobencenos totales (TCB)                                             0.011158
# 1,1,1-tricloroetano (TCE)                                                  0.008926
# Óxido de etileno                                                           0.008926
# Hexafluoruro de azufre (SF6)                                               0.006695
# 1,1,2,2-tetracloroetano                                                    0.006695
# 1,2,3,4,5,6-hexaclorociclohexano (HCH)                                     0.002232
# Name: Contaminante, dtype: float64

# %% [markdown]
# ### Visualizando el dataframe

# %% [markdown]
# #### Realizamos con MatPlotlib visualizaciones básicas de los Tipos de Contaminantes y Cantidades emitidos al Aire

# %% [markdown]
# Generamos dos histogramas con los totales de emisiones y porcentajes

# %%
figure = plt.figure(figsize=(30,10))

plt.subplot2grid((2,3), (0,0))
dfEmiByComplexReduAir["Contaminante"].value_counts().plot(kind='bar', alpha=0.5)
plt.title('Contaminantes, Totales Eventos 2001-2015')

plt.subplot2grid((2,3), (0,1))
dfEmiByComplexReduAir["Contaminante"].value_counts(normalize=True).plot(kind='bar', alpha=0.5)

plt.title('Contaminantes, Porcentajes Totales Eventos 2001-2015')

plt.show()

# %% [markdown]
# Calculamos las frecuencas relativas por tipo de Contaminantes emitidos para obtener porcentajes

# %% [markdown]
# Obtenemos un gráfico circular sencillo, observamos que el Amoniaco es uno de los Contaminantes más habituales, seguido por los Óxidos de Nitrogeno, Dióxido de Carbono y Metano

# %%
# Gráfico de tarta de porcentajes de Tipos de Contaminantes emitidos al Aire.
plot = dfEmiByComplexReduAir["Contaminante"].value_counts().plot(kind='pie', autopct='%.1f', 
                                            figsize=(10, 10),
                                            title='Totales de Emisiones por Contaminantes 2001-2015')

# %% [markdown]
# Obtenemos los diez Contaminantes más numerosos por la suma de Kilogramos emitidos a la atmosfera periodo 2001-2015

# %%
(dfEmiByComplexReduAir.groupby('Contaminante')[['Total_Kg']].sum()).sort_values(by='Total_Kg', ascending=False).head(10)
# Out:
#                                                         Total_Kg
# Contaminante
# Dióxido de carbono (CO2)                            2.006112e+12
# Óxidos de azufre (SOx/SO2)                          9.020753e+09
# Óxidos de nitrógeno (NOx/NO2)                       5.632728e+09
# Monóxido de carbono (CO)                            3.798864e+09
# Metano (CH4)                                        2.445293e+09
# Compuestos orgánicos volátiles distintos del me...  8.796702e+08
# Amoniaco (NH3)                                      5.828544e+08
# Partículas (PM10)                                   3.823163e+08
# Óxido nitroso (N2O)                                 8.338749e+07
# Cloro y compuestos inorgánicos (como HCl)           3.509602e+07

# %% [markdown]
# Filtramos y quitamos el Amoniaco por ser el mas abundante y el CO2 por ser el mas numeroso en Kgs emmitidos

# %%
dfEmiByComplexReduAirnoNH3noCo2 = dfEmiByComplexReduAir[(dfEmiByComplexReduAir['Contaminante'] != "Amoniaco (NH3)") & (dfEmiByComplexReduAir['Contaminante'] !=  "Dióxido de carbono (CO2)")]

# %% [markdown]
# Ploteamos en un histograma los 10 Contaminantes más numerosos por su Cantidad Emitida a la atmosfera (Kilogramos totales), observamos que aunque el Amoniaco es el más abundante por frecuencia, el Dióxido de Carbono es el más relevante por cantidad

# %%
figure = plt.figure(figsize=(1,40))
(dfEmiByComplexReduAir.groupby('Contaminante')[['Total_Kg']].sum()).sort_values(by='Total_Kg', ascending=False).head(10).plot(kind='bar',alpha=0.5, color='br')

plt.title('Totales por Kg periodo 2001-2015 (Top 8 Contaminantes)')
plt.legend('Totales Kg periodo 2001-2015')
plt.show()

# %% [markdown]
# Ploteamos en un histograma los 8 Contaminantes más numerosos por su Cantidad Emitida a la atmosfera sin el Amoniaco y el CO2 (Kilogramos totales)

# %%
figure = plt.figure(figsize=(1,40))
(dfEmiByComplexReduAirnoNH3noCo2.groupby('Contaminante')[['Total_Kg']].sum()).sort_values(by='Total_Kg', ascending=False).head(10).plot(kind='bar',alpha=0.5, color='br')

plt.title('Totales por Kg periodo 2001-2015 (Top 8 Contaminantes)')
plt.legend('Totales Kg periodo 2001-2015')
plt.show()

# %% [markdown]
# Creamos una tabla de contingenica de porcentajes por tipos de emisiones y año

# %%
# tabla de contingencia en porcentajes relativos  
pd.crosstab(index=dfEmiByComplexReduAir['Year'], columns=dfEmiByComplexReduAir['Contaminante'],
            margins=True).apply(lambda r: r/len(dfEmiByComplexReduAir) *100,
                                axis=1)
# Out:
# Contaminante  1,1,1-tricloroetano (TCE)  1,1,2,2-tetracloroetano  \
# Year
# 2001                           0.000000                 0.000000
# 2002                           0.000000                 0.000000
# 2003                           0.000000                 0.000000
# 2004                           0.002232                 0.000000
# 2005                           0.002232                 0.000000
# 2006                           0.002232                 0.000000
# 2007                           0.000000                 0.000000
# 2008                           0.000000                 0.000000
# 2009                           0.000000                 0.000000
# 2010                           0.000000                 0.000000
# 2011                           0.002232                 0.000000
# 2012                           0.000000                 0.002232
# 2013                           0.000000                 0.002232
# 2014                           0.000000                 0.002232
# 2015                           0.000000                 0.000000
# All                            0.008926                 0.006695
#
# Contaminante  1,2,3,4,5,6-hexaclorociclohexano (HCH)  1,2-dicloroetano (DCE)  \
# Year
# 2001                                        0.000000                0.002232
# 2002                                        0.000000                0.002232
# 2003                                        0.000000                0.000000
# 2004                                        0.000000                0.000000
# 2005                                        0.000000                0.000000
# 2006                                        0.002232                0.000000
# 2007                                        0.000000                0.000000
# 2008                                        0.000000                0.000000
# 2009                                        0.000000                0.002232
# 2010                                        0.000000                0.002232
# 2011                                        0.000000                0.002232
# 2012                                        0.000000                0.002232
# 2013                                        0.000000                0.004463
# 2014                                        0.000000                0.004463
# 2015                                        0.000000                0.004463
# All                                         0.002232                0.026779
#
# Contaminante  Amoniaco (NH3)  Antraceno  Arsénico y compuestos (como As)  \
# Year
# 2001                2.106626   0.000000                         0.071411
# 2002                1.727254   0.000000                         0.071411
# 2003                1.854455   0.000000                         0.080337
# 2004                2.367722   0.000000                         0.091495
# 2005                2.070920   0.000000                         0.084801
# 2006                2.463681   0.000000                         0.078106
# 2007                2.990337   0.002232                         0.095959
# 2008                3.157707   0.002232                         0.087032
# 2009                3.615184   0.004463                         0.078106
# 2010                3.336234   0.002232                         0.066948
# 2011                3.427730   0.002232                         0.080337
# 2012                3.273750   0.002232                         0.073643
# 2013                3.559394   0.002232                         0.055790
# 2014                4.157461   0.002232                         0.060253
# 2015                4.530138   0.002232                         0.062485
# All                44.638593   0.022316                         1.138113
#
# Contaminante  Benceno   Cadmio y compuestos (como Cd)  \
# Year
# 2001          0.044632                       0.091495
# 2002          0.037937                       0.093727
# 2003          0.044632                       0.098190
# 2004          0.058021                       0.116043
# 2005          0.055790                       0.093727
# 2006          0.066948                       0.153980
# 2007          0.075874                       0.169601
# 2008          0.073643                       0.127201
# 2009          0.066948                       0.084801
# 2010          0.069179                       0.078106
# 2011          0.053558                       0.082569
# 2012          0.058021                       0.073643
# 2013          0.064716                       0.073643
# 2014          0.053558                       0.058021
# 2015          0.042400                       0.064716
# All           0.865859                       1.459463
#
# Contaminante  Cianuro de hidrógeno (HCN)     ...      Tetraclorometano (TCM)  \
# Year                                         ...
# 2001                            0.013390     ...                    0.004463
# 2002                            0.013390     ...                    0.002232
# 2003                            0.008926     ...                    0.002232
# 2004                            0.008926     ...                    0.002232
# 2005                            0.011158     ...                    0.006695
# 2006                            0.011158     ...                    0.004463
# 2007                            0.024548     ...                    0.000000
# 2008                            0.046863     ...                    0.000000
# 2009                            0.022316     ...                    0.000000
# 2010                            0.017853     ...                    0.000000
# 2011                            0.020084     ...                    0.004463
# 2012                            0.017853     ...                    0.002232
# 2013                            0.013390     ...                    0.006695
# 2014                            0.015621     ...                    0.002232
# 2015                            0.006695     ...                    0.004463
# All                             0.252170     ...                    0.042400
#
# Contaminante  Triclorobencenos totales (TCB)  Tricloroetileno   \
# Year
# 2001                                0.000000          0.006695
# 2002                                0.000000          0.006695
# 2003                                0.000000          0.002232
# 2004                                0.002232          0.004463
# 2005                                0.002232          0.002232
# 2006                                0.004463          0.004463
# 2007                                0.000000          0.004463
# 2008                                0.002232          0.006695
# 2009                                0.000000          0.000000
# 2010                                0.000000          0.000000
# 2011                                0.000000          0.000000
# 2012                                0.000000          0.000000
# 2013                                0.000000          0.002232
# 2014                                0.000000          0.004463
# 2015                                0.000000          0.002232
# All                                 0.011158          0.046863
#
# Contaminante  Triclorometano  Zinc y compuestos (como Zn)  Óxido de etileno  \
# Year
# 2001                0.004463                     0.100422          0.000000
# 2002                0.004463                     0.120506          0.000000
# 2003                0.004463                     0.124969          0.000000
# 2004                0.000000                     0.129433          0.000000
# 2005                0.000000                     0.127201          0.000000
# 2006                0.000000                     0.116043          0.000000
# 2007                0.006695                     0.167370          0.002232
# 2008                0.000000                     0.145054          0.002232
# 2009                0.002232                     0.133896          0.002232
# 2010                0.002232                     0.131664          0.002232
# 2011                0.004463                     0.136127          0.000000
# 2012                0.002232                     0.140590          0.000000
# 2013                0.002232                     0.147285          0.000000
# 2014                0.004463                     0.142822          0.000000
# 2015                0.002232                     0.149517          0.000000
# All                 0.040169                     2.012899          0.008926
#
# Contaminante  Óxido nitroso (N2O)  Óxidos de azufre (SOx/SO2)  \
# Year
# 2001                     0.084801                    0.365982
# 2002                     0.044632                    0.314655
# 2003                     0.066948                    0.301265
# 2004                     0.087032                    0.334739
# 2005                     0.104885                    0.296802
# 2006                     0.107117                    0.359287
# 2007                     0.124969                    0.374908
# 2008                     0.147285                    0.296802
# 2009                     0.122738                    0.232086
# 2010                     0.107117                    0.241012
# 2011                     0.158443                    0.247707
# 2012                     0.127201                    0.234317
# 2013                     0.118275                    0.216465
# 2014                     0.124969                    0.194149
# 2015                     0.120506                    0.203075
# All                      1.646917                    4.213251
#
# Contaminante  Óxidos de nitrógeno (NOx/NO2)         All
# Year
# 2001                               0.513267    5.326817
# 2002                               0.526656    4.860414
# 2003                               0.548972    5.279954
# 2004                               0.653857    6.444846
# 2005                               0.698489    5.944969
# 2006                               0.731963    6.717101
# 2007                               0.765437    7.940015
# 2008                               0.765437    7.777108
# 2009                               0.682868    7.348642
# 2010                               0.660552    6.975966
# 2011                               0.689563    7.192430
# 2012                               0.649394    6.685858
# 2013                               0.602531    6.685858
# 2014                               0.560130    7.232599
# 2015                               0.551204    7.587423
# All                                9.600321  100.000000
#
# [16 rows x 47 columns]

# %% [markdown]
# Generamos una tabla de contingencia de totales de Kilogramos Contaminantes por Tipo y Año emitidos en España

# %%
#CAMBIAR Y AGRUPAR POR TOTALES DE KG!!!!!!!!!!!!!!!
df1= pd.crosstab(index=dfEmiByComplexReduAir['Year'], columns=dfEmiByComplexReduAir['Contaminante'],
            margins=True).apply(lambda r: r/len(dfEmiByComplexReduAir) *100,
                                axis=1)

# %% [markdown]
# Ploteamos esta última con un gráfico "Bar Plot", para ver su evolución en los años de estudio

# %%
X=[]
for i in range(0,15):
    X.append(df1.iloc[i].sum())
    
Y =np.arange(2001,2015,1)

plt.bar(range(len(X)), X)
plt.xticks(np.arange(len(X)), Y,rotation='vertical')
plt.title('Evolución por Años emisión Atmósfera')
plt.xlabel("Años") 
plt.ylabel("Totales Kgs Contaminantes") 
plt.show()

# %% [markdown]
# #### Ploteando con Seaborn

# %%
import seaborn as sns
sns.jointplot(data=dfEmiByComplexReduAir, x='Year', y='Total_Kg');

# %%
sns.jointplot(data=dfEmiByComplexReduAir, x='Year', y='Total_Kg', kind='kde');

# %% [markdown]
# Distribución por Latitud-Longitud

# %%
# Show the results of a linear regression
df = dfEmiByComplexReduAir
tips = sns.load_dataset("tips")
g = sns.lmplot(x="Longitud", y="Latitud", data=df)
