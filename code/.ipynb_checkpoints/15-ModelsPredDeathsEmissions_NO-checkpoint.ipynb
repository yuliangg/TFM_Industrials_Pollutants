# %% [markdown]
# # Models DeathsEmissions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_modelling = pd.read_csv('../data/csv/model_csv/df_model_dist_encoding.csv', sep=';', encoding= 'utf-8',  compression='gzip', index_col=False)

# %%
df_modelling.shape
# Out:
# (85526, 10)

# %%
df_modelling.drop(['Unnamed: 0'], axis=1, inplace=True) #Borramos columnas innecesarias

# %%
pd.options.display.max_columns = None

# %%
df_modelling.sample(3000)
# Out:
#        target  Sexo  AnioCumplidos  TamanioMuniResi  total_anios_Expo_Id  \
# 44058       0     0             74                6                    2
# 31271       1     1             61                5                    3
# 68079       0     0             84                2                    5
# 45812       0     1             59                6                    6
# 43508       0     0             76                6                    3
# 65629       0     0             81                2                    1
# 55161       0     0             74                4                    3
# 74408       0     0             79                2                    1
# 8308        1     0             55                6                    3
# 20723       0     1             67                6                    1
# 67925       0     1             85                4                    3
# 55023       0     1             77                4                    3
# 30649       0     1             66                6                    1
# 45043       0     1             91                2                    1
# 21193       0     1             79                3                    1
# 31253       0     1             80                5                    3
# 83069       0     1             47                6                    1
# 896         0     1             82                5                    5
# 2965        1     1             77                6                    5
# 51642       0     0             69                3                    1
# 70609       1     0             57                3                    3
# 15232       1     1             77                6                    4
# 41512       0     0             75                6                    1
# 61574       0     1             74                6                    2
# 57311       0     1             69                3                    6
# 84066       0     1             86                2                    1
# 82298       0     0            103                4                    1
# 8570        1     1             76                6                    3
# 3525        0     1             83                6                    5
# 10451       0     0             89                6                    4
# ...       ...   ...            ...              ...                  ...
# 38735       0     1             80                5                    5
# 84723       0     0             89                4                    1
# 47112       0     1             87                6                    6
# 20477       0     0             80                6                    1
# 78652       0     1             66                6                    3
# 76867       0     0             80                5                    1
# 43629       0     0             85                3                    3
# 35481       1     1             51                6                    1
# 26522       0     0             46                6                    2
# 15679       0     0             84                3                    2
# 71655       0     1             83                6                    3
# 3266        0     1             89                6                    5
# 23493       0     0             84                5                    1
# 63052       0     0            104                3                    1
# 23097       1     1             79                5                    1
# 1863        0     1             79                6                    5
# 81465       0     1             97                6                    2
# 24041       0     1             81                5                    1
# 36825       0     1             81                5                    1
# 48182       0     0             90                6                    6
# 5506        1     1             52                6                    5
# 12969       0     1             86                4                    2
# 12126       0     0             88                6                    4
# 18571       1     1             60                6                    5
# 51353       0     1             70                5                    6
# 38099       0     0             82                6                    1
# 31356       0     1             72                5                    3
# 78227       0     1             71                2                    3
# 35878       0     1             66                4                    1
# 28717       0     1             59                5                    3
#
#        Total_Kg_expo  Distance  Cont_Dióxido de carbono (CO2)  \
# 44058   3.452836e+06      4904                              0
# 31271   1.682000e+09       564                              1
# 68079   7.879900e+06      5571                              0
# 45812   2.387096e+06       427                              0
# 43508   4.111000e+05       185                              0
# 65629   1.230000e+05      8952                              0
# 55161   2.296364e+06      7690                              0
# 74408   8.643373e+05      6408                              0
# 8308    8.162252e+08      4530                              1
# 20723   1.020000e+08      6072                              1
# 67925   1.218859e+06      2576                              0
# 55023   2.296364e+06      7690                              0
# count  85526.000000  85526.000000   85526.000000     85526.000000
# mean       0.161588      0.588979      75.289818         4.931951
# std        0.368075      0.492022      13.563996         1.328930
# min        0.000000      0.000000       0.000000         2.000000
# 25%        0.000000      0.000000      67.000000         4.000000
# 50%        0.000000      1.000000      78.000000         6.000000
# 75%        0.000000      1.000000      85.000000         6.000000
# max        1.000000      1.000000     108.000000         6.000000
#
#        total_anios_Expo_Id  Total_Kg_expo      Distance  \
# count         85526.000000   8.552600e+04  85526.000000
# mean              2.780862   9.093853e+08   3740.915523
# std               1.792664   1.738742e+09   2456.168412
# min               1.000000   5.033000e+04     17.000000
# 25%               1.000000   5.472680e+05   1334.000000
# 50%               2.000000   3.452836e+06   3875.000000
# 75%               4.000000   9.396260e+08   5657.000000
# max               8.000000   9.300000e+09   9499.000000
#
#        Cont_Dióxido de carbono (CO2)  Cont_Partículas (PM10)
# count                   85526.000000            85526.000000
# mean                        0.447992                0.552008
# std                         0.497291                0.497291
# min                         0.000000                0.000000
# 25%                         0.000000                0.000000
# 50%                         0.000000                1.000000
# 75%                         1.000000                1.000000
# max                         1.000000                1.000000

# %% [markdown]
# ### Pre-processing: Feature Scaling

# %% [markdown]
# Procedemos a estandarizar variables numéricas, para ello utilizamos dos métodos diferentes, para comparar resultados

# %%
from sklearn import preprocessing

# %% [markdown]
# #### Vamos a aplicar el escalado estandar al dataframe completo dividiendo un set de entrenamiento y test

# %% [markdown]
# Aplicamos el escalado estándar al set de entrenamiento

# %%
from sklearn import preprocessing
#Columns of interest for preprocessing
columnas = ['AnioCumplidos', 'TamanioMuniResi', 'total_anios_Expo_Id', 'Total_Kg_expo','Distance']

#Estandarización sólo para ejemplo de comparación
std_scale  = preprocessing.StandardScaler().fit(df_modelling) 
df_std = std_scale.transform(df_modelling) #Solo para utilizar el array en la prueba siguiente.

#Escalamos las columnas de interes.
df_modelling[columnas] = preprocessing.StandardScaler().fit_transform(df_modelling[columnas]) #Solo columnas de interés escaladas
df_model_std = df_modelling #asignamos para cambiar nombre

# %%
df_model_std.head()
# Out:
#    target  Sexo  AnioCumplidos  TamanioMuniResi  total_anios_Expo_Id  \
# 0       1     1      -0.979792        -0.701283             1.237907
# 1       0     0       0.420983        -0.701283             1.237907
# 2       0     0      -0.463717        -0.701283             1.237907
# 3       0     0      -1.938217        -0.701283             1.237907
# 4       0     0       1.084508        -0.701283             1.237907
#
#    Total_Kg_expo  Distance  Cont_Dióxido de carbono (CO2)  \
# 0       3.686373  0.121769                              1
# 1       3.686373  0.121769                              1
# 2       3.686373  0.121769                              1
# 3       3.686373  0.121769                              1
# 4       3.686373  0.121769                              1
#
#    Cont_Partículas (PM10)
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
from sklearn.model_selection import train_test_split

X = df_model_std.values[:,1:]
y = df_model_std.values[:,0]

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.30, random_state=12345)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

clf1 = DecisionTreeClassifier(random_state=4)
clf2 = GaussianNB()
clf4 = KNeighborsClassifier(n_neighbors=2)
clf3 = LogisticRegression()

# %%
from sklearn.model_selection import cross_val_score
print (cross_val_score(clf1, X, y, cv=10,scoring="accuracy").mean())
print (cross_val_score(clf2, X, y, cv=10,scoring="accuracy").mean())
print (cross_val_score(clf4, X, y, cv=10,scoring="accuracy").mean())
print (cross_val_score(clf3, X, y, cv=10,scoring="accuracy").mean())
# Out:
# 0.792144704504
# 0.837324372752
# 0.815658479615
# 0.834962473848

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
clf1.fit(X_train,y_train)
clf2.fit(X_train,y_train)
clf3.fit(X_train,y_train)
clf4.fit(X_train,y_train)
preds={}
preds["DecisionTreeClassifier"]=clf1.predict(X_test)
preds["Gaussian"]=clf2.predict(X_test)
preds["Logistic"]=clf3.predict(X_test)
preds["KNeighbors"]=clf4.predict(X_test)

# %%
import seaborn as sns
sns.heatmap(pd.DataFrame(preds).corr())
plt.show()

# %%
from sklearn.ensemble import VotingClassifier
eclf = VotingClassifier(estimators=[('tree', clf1), ('Logistic', clf3),("Kneighbors",clf4)])
print (cross_val_score(eclf, X, y, cv=10,scoring="accuracy").mean())
# Out:
# 0.83091684579

# %% [markdown]
# Stacking

# %%
from mlxtend.classifier import StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
mr = LogisticRegression()
sclf = StackingClassifier(classifiers=[clf2, clf3, clf4], meta_classifier=mr)

# %%
print (cross_val_score(clf1, X, y, cv=10,scoring="accuracy").mean())
print (cross_val_score(clf2, X, y, cv=10,scoring="accuracy").mean())
print (cross_val_score(clf3, X, y, cv=10,scoring="accuracy").mean())
print (cross_val_score(clf4, X, y, cv=10,scoring="accuracy").mean())
print (cross_val_score(sclf, X, y, cv=10,scoring="accuracy").mean())
# Out:
# 0.792144704504
# 0.837324372752
# 0.834962473848
# 0.815658479615
# 0.815658479615

# %%
print (cross_val_score(sclf, X, y, cv=10,scoring="accuracy").mean())
# Out:
# 0.815658479615

# %% [markdown]
# Bagging

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bclf = BaggingClassifier(base_estimator=LogisticRegression(),n_estimators=100)

# %%
print (cross_val_score(bclf, X, y, cv=10,scoring="accuracy").mean())
# Out:
# 0.834950780677

# %%
bclf = BaggingClassifier(base_estimator=GaussianNB(),n_estimators=100)

# %%
print (cross_val_score(bclf, X, y, cv=10,scoring="accuracy").mean())
# Out:
# 0.837640051461

# %% [markdown]
# Métricas

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
rand = XGBClassifier(n_estimators=3000)

# %%
rand.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=3000,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
print(accuracy_score(y_test,rand.predict(X_test)))
# Out:
# 0.838880661002

# %%
print(classification_report(y_test,rand.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.84      1.00      0.91     21526
#         1.0       0.43      0.00      0.00      4132
#
# avg / total       0.77      0.84      0.77     25658

# %%
sns.heatmap(confusion_matrix(y_test,rand.predict(X_test)),annot=True)
plt.show()
