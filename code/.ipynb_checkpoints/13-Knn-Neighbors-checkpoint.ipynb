# %% [markdown]
# # Model Knn-Neighbors

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Leemos el csv con las geometrias y distancia al punto contaminante

# %%
df_modelling = pd.read_csv('../data/csv/model_csv/df_model_geom.csv', sep=';', encoding= 'utf-8',  compression='gzip', index_col=False)

# %%
df_modelling.shape
# Out:
# (85526, 29)

# %%
df_modelling.drop(['Unnamed: 0'], axis=1, inplace=True) #Borramos columnas innecesarias

# %%
pd.options.display.max_columns = None

# %%
df_modelling.sample(5100)
# Out:
#             Id  ProvinciaReside  MunicipioReside  Sexo  AnioCumplidos  \
# 57871   794823               43               51     6             83
# 67562   952207               50              297     1             85
# 36290  1116729                8              221     1             51
# 42426   858650               46              250     1             50
# 47623  1068069                8               19     1             81
# 65177  1151603                8               77     1             76
# 22632   257202               28              106     6              2
# 51581   814840               46              145     1             78
# 56822   578707               33               24     1             67
# 41983   853337               46              250     6             71
# 2528   1058828                8               19     1             62
# 22109   189251               20               69     1             57
# 15672   918445               48               78     6             64
# 65798   931895               50              297     1             85
# 59339    99350               15               30     1             84
# 20137   151044               18                3     6             45
# 31108    22390               11               20     1             87
# 28346   584130               33               24     1             64
# 64649  1003178                8              101     6             91
# 83449    22363               11               20     1             80
# 39912   807635               46              102     1             86
# 7162    785289               43              148     1             48
# 57026   581248               33               24     6             95
# 32735    85201               14               21     1             80
# 52473    29278               11               22     6             69
# 41820   851176               46              250     1             85
# 80240   186399               20               69     1             70
# 56931   580020               33               24     6             89
# 75690   120744               15               78     1             79
# 4745   1085860                8               19     6            102
# ...        ...              ...              ...   ...            ...
# 82348   110491               15               36     6             95
# 79401  1022323                8               15     1             71
# 77947  1010741                8              113     6             87
# 58456   706270               39               75     6             71
# 70007   239731               25              120     1             59
# 68044   568783               33               14     6             62
# 52762    43653               11                4     1             56
# 53466   739638               41                4     1             77
# 83645    24894               11               20     6             81
# 72609   173934               20               17     1             84
# 42919   864523               46              250     1             76
# 45490   496407                3               65     6             93
# 44108    55416               12               40     6             91
# 33896  1161468                9               59     1             78
# 28976   691339               38               38     6             87
# 57918   164359               19               24     6             96
# 4325   1080612                8               19     6             58
# 82102   993126                7               40     1             47
# 59209    98129               15               30     6             72
# 51760  1117694                8              231     1             64
# 37938    56760               12               40     6             57
# 13044   960679               52                1     6             53
# 34629  1018962                8              124     6             53
# 56945   580182               33               24     1             66
# 67578   952395               50              297     1             80
# 14499   984557                7               40     1             90
# 47302  1064091                8               19     1             68
# 52519    29767               11               22     1             77
# 78140  1115189                8              218     1             62
# 4355   1080924                8               19     1             63
#
#        TamanioMuniResi  CausaMortaReduc  NivelEstudios  \
# 57871                2               93              3
# 67562                6               12              2
# 36290                2               18              6
# 42426                6               18              5
# 47623                6               13              2
# 65177                3               11              2
# 22632                5               22             99
# 51581                3               64              2
# 56822                5               64              4
# 41983                6               18              3
# 2528                 6               18              5
# 22109                6               93              5
# 15672                3               18              4
# 65798                6               18              9
# 59339                6               31              4
# 20137                2               23              4
# 31108                5               18              3
# 28346                5               14              5
# 64649                5               31              4
# 83449                5               93              3
# 39912                3               12              2
# 7162                 6               18              4
# 57026                5               18              3
# 68044                    5   7.879900e+06   C02
# 52762                    5   4.982000e+06   C18
# 53466                    3   1.289500e+06   C80
# 83645                    1   2.260000e+05   C02
# 72609                    2   7.965896e+05   C61
# 42919                    1   4.129000e+05   C34
# 45490                    1   1.094000e+05   J44
# 44108                    2   3.452836e+06   C17
# 33896                    1   1.040000e+08   J44
# 28976                    3   2.651928e+09   D47
# 57918                    1   6.450000e+05   J98
# 4325                     5   3.901070e+09   C71
# 82102                    2   3.532000e+05   C10
# 59209                    4   3.679200e+06   C20
# 51760                    1   1.120000e+05   C34
# 37938                    1   1.110000e+08   C16
# 13044                    2   2.651777e+08   C50
# 34629                    2   9.060000e+08   C34
# 56945                    6   4.745047e+06   C34
# 67578                    4   2.428500e+06   C34
# 14499                    4   2.354134e+09   C67
# 47302                    6   2.387096e+06   C18
# 52519                    6   4.846800e+06   C67
# 78140                    1   6.930000e+05   C15
# 4355                     5   3.901070e+09   C67
#
#                                        Descripcion_Cod_3  target  \
# 57871  INHALACION_E_INGESTION_DE_OTROS_OBJETOS_QUE_CA...       0
# 67562                            TUMOR_MALIGNO_DEL_COLON       0
# 36290        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 42426        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 47623                            TUMOR_MALIGNO_DEL_RECTO       0
# 65177                         TUMOR_MALIGNO_DEL_ESTOMAGO       0
# 22632  TUMOR_MALIGNO_OTROS_TEJIDOS_CONJUNTIVOS_Y_DE_T...       0
# 51581  OTRAS_ENFERMEDADES_PULMONARES_OBSTRUCTIVAS_CRO...       0
# 56822  OTRAS_ENFERMEDADES_PULMONARES_OBSTRUCTIVAS_CRO...       0
# 41983        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 2528         TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 22109  INHALACION_E_INGESTION_DE_OTROS_OBJETOS_QUE_CA...       0
# 15672        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 65798        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 59339                TUMOR_MALIGNO_DE_LA_VEJIGA_URINARIA       0
# 20137                           TUMOR_MALIGNO_DE_LA_MAMA       0
# 31108        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 28346  TUMOR_MALIGNO_DEL_HIGADO_Y_DE_LAS_VIAS_BILIARE...       0
# 64649                TUMOR_MALIGNO_DE_LA_VEJIGA_URINARIA       0
# 83449  INHALACION_E_INGESTION_DE_OTROS_OBJETOS_QUE_CA...       0
# 39912                            TUMOR_MALIGNO_DEL_COLON       0
# 7162         TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 57026        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 32735                     OTROS_TRASTORNOS_RESPIRATORIOS       0
# 52473           TUMOR_MALIGNO_DE_SITIOS_NO_ESPECIFICADOS       0
# 41820           TUMOR_MALIGNO_DE_SITIOS_NO_ESPECIFICADOS       0
# 80240        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 56931                           TUMOR_MALIGNO_DE_LA_MAMA       0
# 75690  OTRAS_ENFERMEDADES_PULMONARES_OBSTRUCTIVAS_CRO...       0
# 4745   INHALACION_E_INGESTION_DE_OTROS_OBJETOS_QUE_CA...       0
# ...                                                  ...     ...
# 82348  INFEC_AGUD_NO_ESPECIFICADA_DE_LAS_VIAS_RESPIRA...       0
# 79401                       TUMOR_MALIGNO_DE_LA_PROSTATA       0
# 77947  MIELOMA_MULTIPLES_Y_TUMORES_MALIGNOS_DE_CELULA...       0
# 58456                            TUMOR_MALIGNO_DEL_COLON       0
# 70007  MIELOMA_MULTIPLES_Y_TUMORES_MALIGNOS_DE_CELULA...       0
# 68044  TUMOR_MALIGNO_DE_OTRAS_PARTES_Y_DE_LAS_NO_ESPE...       0
# 52762                            TUMOR_MALIGNO_DEL_COLON       0
# 53466           TUMOR_MALIGNO_DE_SITIOS_NO_ESPECIFICADOS       0
# 83645  TUMOR_MALIGNO_DE_OTRAS_PARTES_Y_DE_LAS_NO_ESPE...       0
# 72609                       TUMOR_MALIGNO_DE_LA_PROSTATA       0
# 42919        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 45490  OTRAS_ENFERMEDADES_PULMONARES_OBSTRUCTIVAS_CRO...       0
# 44108                TUMOR_MALIGNO_DEL_INTESTINO_DELGADO       0
# 33896  OTRAS_ENFERMEDADES_PULMONARES_OBSTRUCTIVAS_CRO...       0
# 28976  OTROS_TUMORES_DE_COMPORTAMIENTO_INCIERTO_O_DES...       0
# 57918                     OTROS_TRASTORNOS_RESPIRATORIOS       0
# 4325                          TUMOR_MALIGNO_DEL_ENCEFALO       0
# 82102                     TUMOR_MALIGNO_DE_LA_OROFARINGE       0
# 59209                            TUMOR_MALIGNO_DEL_RECTO       0
# 51760        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 37938                         TUMOR_MALIGNO_DEL_ESTOMAGO       0
# 13044                           TUMOR_MALIGNO_DE_LA_MAMA       0
# 34629        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 56945        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 67578        TUMOR_MALIGNO_DE_LOS_BRONQUIOS_Y_DEL_PULMON       1
# 14499                TUMOR_MALIGNO_DE_LA_VEJIGA_URINARIA       0
# 47302                            TUMOR_MALIGNO_DEL_COLON       0
# 52519                TUMOR_MALIGNO_DE_LA_VEJIGA_URINARIA       0
# 78140                          TUMOR_MALIGNO_DEL_ESOFAGO       0
# 4355                 TUMOR_MALIGNO_DE_LA_VEJIGA_URINARIA       0
#
#                                       geometry_death  \
# 57871                      POINT (1.636739 41.19884)
# 67562  POINT (-0.8765379000000014 41.65629000000001)
# 36290                      POINT (2.075544 41.38576)
# min    5.000000e+00         1.000000         1.000000      1.000000
# 25%    2.994660e+05         8.000000        20.000000      1.000000
# 50%    7.872880e+05        20.000000        40.000000      1.000000
# 75%    1.013214e+06        38.000000       101.000000      6.000000
# max    1.166867e+06        52.000000       911.000000      6.000000
#
#        AnioCumplidos  TamanioMuniResi  CausaMortaReduc  NivelEstudios  \
# count   85526.000000     85526.000000     85526.000000   85526.000000
# mean       75.289818         4.931951        32.592942       5.742909
# std        13.563996         1.328930        22.166800      12.446900
# min         0.000000         2.000000         6.000000       1.000000
# 25%        67.000000         4.000000        15.000000       3.000000
# 50%        78.000000         6.000000        23.000000       4.000000
# 75%        85.000000         6.000000        58.000000       5.000000
# max       108.000000         6.000000        93.000000      99.000000
#
#             Latitud      Longitud    Habitantes        Hombres        Mujeres  \
# count  85526.000000  85526.000000  8.552600e+04   85526.000000   85526.000000
# mean      40.327955     -2.491245  3.915583e+05  187985.258974  203573.081426
# std        3.514643      4.592454  5.001371e+05  237976.591683  262189.200077
# min       28.124820    -16.314780  1.020000e+02      54.000000      48.000000
# 25%       39.470240     -4.779152  7.015500e+04   34876.000000   35199.000000
# 50%       41.387920     -1.984421  2.075320e+05  102781.000000  105895.000000
# 75%       42.817210      2.045171  3.818470e+05  186191.000000  195656.000000
# max       43.609970      4.264211  1.621537e+06  771570.000000  849967.000000
#
#          CodigoPRTR     LongitudE      LatitudE  total_anios_Expo_Id  \
# count  85526.000000  85526.000000  85526.000000         85526.000000
# mean    3368.664219     -2.490242     40.327924             2.780862
# std     2132.720507      4.595470      3.512169             1.792664
# min       11.000000    -16.261808     28.144978             1.000000
# 25%     1593.000000     -4.779383     39.469907             1.000000
# 50%     3469.000000     -1.969660     41.388362             2.000000
# 75%     4892.000000      2.040820     42.812227             4.000000
# max     8702.000000      4.264603     43.582673             8.000000
#
#        Total_Kg_expo        target      Distance
# count   8.552600e+04  85526.000000  85526.000000
# mean    9.093853e+08      0.161588   3740.915523
# std     1.738742e+09      0.368075   2456.168412
# min     5.033000e+04      0.000000     17.000000
# 25%     5.472680e+05      0.000000   1334.000000
# 50%     3.452836e+06      0.000000   3875.000000
# 75%     9.396260e+08      0.000000   5657.000000
# max     9.300000e+09      1.000000   9499.000000

# %% [markdown]
# Vamos a normalizar ciertas variables que consideramos importantes para el modelo para poder tratarlas luego

# %%
df_model_fil = df_modelling[['target','Sexo', 'AnioCumplidos', 'TamanioMuniResi', 'total_anios_Expo_Id', 'Contaminante','Total_Kg_expo','Distance']]
df_model_fil_with_geom = df_modelling[['target','Sexo', 'AnioCumplidos', 'TamanioMuniResi', 'total_anios_Expo_Id', 'Contaminante','Total_Kg_expo','Distance','geometry_death','Latitud','Longitud','Habitantes','LatitudE','LongitudE']]

# %% [markdown]
# Comprobamos las variables tipo object

# %%
obj_df = df_model_fil.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#                Contaminante
# 0  Dióxido de carbono (CO2)
# 1  Dióxido de carbono (CO2)
# 2  Dióxido de carbono (CO2)
# 3  Dióxido de carbono (CO2)
# 4  Dióxido de carbono (CO2)

# %% [markdown]
# Comprobamos nulos

# %%
obj_df[obj_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Contaminante]
# Index: []

# %% [markdown]
# ### Pre-Processing: Encoding Categorical Values

# %% [markdown]
# Optamos por este tipo de codificación para no asignar pesos específicos por cada valor

# %%
df_model_fil= pd.get_dummies(df_model_fil, columns=["Contaminante"], prefix=["Cont"])
df_model_fil_with_geom= pd.get_dummies(df_model_fil_with_geom, columns=["Contaminante"], prefix=["Cont"]) #Para utilizar en el modelo espacial

# %%
df_model_fil.head()
# Out:
#    target  Sexo  AnioCumplidos  TamanioMuniResi  total_anios_Expo_Id  \
# 0       1     1             62                4                    5
# 1       0     6             81                4                    5
# 2       0     6             69                4                    5
# 3       0     6             49                4                    5
# 4       0     6             90                4                    5
#
#    Total_Kg_expo  Distance  Cont_Dióxido de carbono (CO2)  \
# 0   7.319000e+09      4040                              1
# 1   7.319000e+09      4040                              1
# 2   7.319000e+09      4040                              1
# 3   7.319000e+09      4040                              1
# 4   7.319000e+09      4040                              1
#
#    Cont_Partículas (PM10)
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
df_model_fil['Sexo'].dtype
# Out:
# dtype('int64')

# %%
df_model_fil['Sexo']= df_model_fil['Sexo'].replace(6,0)
df_model_fil_with_geom['Sexo']= df_model_fil_with_geom['Sexo'].replace(6,0) #Para utilizar en el modelo espacial

# %%
df_model_fil['AnioCumplidos'].describe()
# Out:
# count    85526.000000
# mean        75.289818
# std         13.563996
# min          0.000000
# 25%         67.000000
# 50%         78.000000
# 75%         85.000000
# max        108.000000
# Name: AnioCumplidos, dtype: float64

# %%
df_model_fil.head()
# Out:
#    target  Sexo  AnioCumplidos  TamanioMuniResi  total_anios_Expo_Id  \
# 0       1     1             62                4                    5
# 1       0     0             81                4                    5
# 2       0     0             69                4                    5
# 3       0     0             49                4                    5
# 4       0     0             90                4                    5
#
#    Total_Kg_expo  Distance  Cont_Dióxido de carbono (CO2)  \
# 0   7.319000e+09      4040                              1
# 1   7.319000e+09      4040                              1
# 2   7.319000e+09      4040                              1
# 3   7.319000e+09      4040                              1
# 4   7.319000e+09      4040                              1
#
#    Cont_Partículas (PM10)
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# Observamos rangos de dos de las variables numéricas que escalaremos más adelante

# %%
df_model_fil[['Total_Kg_expo','total_anios_Expo_Id']].describe()
# Out:
#        Total_Kg_expo  total_anios_Expo_Id
# count   8.552600e+04         85526.000000
# mean    9.093853e+08             2.780862
# std     1.738742e+09             1.792664
# min     5.033000e+04             1.000000
# 25%     5.472680e+05             1.000000
# 50%     3.452836e+06             2.000000
# 75%     9.396260e+08             4.000000
# max     9.300000e+09             8.000000

# %% [markdown]
# Salvamos a csv para disponer del dataframe en el siguiente modelo

# %%
df_model_fil.to_csv('../data/csv/model_csv/df_model_dist_encoding.csv', sep=';', encoding= 'utf-8',  compression='gzip')
df_model_fil_with_geom.to_csv('../data/csv/model_csv/df_model_geom_encoding.csv', sep=';', encoding= 'utf-8',  compression='gzip')

# %% [markdown]
# ### Knn-Neightbors: approach 1

# %% [markdown]
# Hacemos una primera aproximación sin valores escalados sólo con los del dataframe filtrado del inicio

# %%
X = df_model_fil[['Sexo', 'AnioCumplidos', 'TamanioMuniResi', 'total_anios_Expo_Id', 'Total_Kg_expo', 'Distance']].values
y = df_model_fil["target"]

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# Entrenamos el primer modelo muy sencillo

# %%
clf.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %% [markdown]
# NOTA*** Codificación INE para tamaño municipios:
# 1:	Municipio menor o igual a 10.000 habitantes
# 2:	 De 10.001 a 20.000
# 3:	 De 20.001 a 50.000
# 4:	 De 50.001 a 100.000
# 5:	 Mayor de 100.000
# 6:	 capital de provincia

# %% [markdown]
# Hacemos unas primeras predicciones, ejemplo para un varón de 80 años de capital de provincia con 2 años de exposición al contaminante (300 Kg acumulados) y que vive a una distancia de 1000 metros del foco contaminante. No se tiene en cuenta el tipo de contaminante.

# %%
clf.predict([[1,80,6,2,300,1000]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# Se observa en una primera aproximación que la edad es un factor de riesgo de fallecimiento por cancer de pulmón (target), pero no sólo en edades avanzadas sino en edades muy tempranas, aunque quizá sea un factor de confusión en el estudio. Igualmente parece ser que la distancia al foco contaminante es muy influyente.

# %% [markdown]
# #### Setting Training and Test Sets

# %% [markdown]
# A continuación vamos a dividir del dataframe en dos datasets, uno de entrenamiento y otro de test, conforme a las variables iniciales X,y (variables sin escalar)

# %%
from sklearn.model_selection import train_test_split
# Train - Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#Dimensión del input para el Train
print (X_train.shape)
# Out:
# (57302, 6)

# %%
#Dimensión del input para el test
print (y_train.shape)
# Out:
# (57302,)

# %% [markdown]
# Establecemos el número de neighors y lo pasamos al clasificador

# %%
clf = KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# Entrenamos con el input Train y el output train

# %%
clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=2, p=2,
#            weights='uniform')

# %% [markdown]
# Hacemos predicción con el Input del dataset Test

# %%
prediccion_test = clf.predict(X_test)
prediccion_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# #### Calculamos la matriz de confusión

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, prediccion_test)
print (cm)
# Out:
# [[22858   818]
#  [ 4285   263]]

# %% [markdown]
# Ploteamos la matriz

# %%
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title('Deaths Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

# %% [markdown]
# Accuray score

# %%
from sklearn.metrics import accuracy_score
accuracy_score(clf.predict(X_test),y_test)
# Out:
# 0.8191964285714286

# %% [markdown]
# Realizamos el cross Validation Score

# %%
# Crossval score
from sklearn.model_selection import cross_val_score
cross_val_score(clf,X,y,cv=10,scoring="accuracy")
# Out:
# array([0.8315211 , 0.76850228, 0.83222261, 0.81807553, 0.81106045,
#        0.82006314, 0.81735267, 0.7717493 , 0.79256314, 0.82916277])

# %% [markdown]
# Calculamos el accuracy medio para nuestro modelo

# %%
np.mean(cross_val_score(clf,X,y,cv=10,scoring="accuracy"))
# Out:
# 0.809227298350012

# %% [markdown]
# Vamos a utilizar la librria GridSearchCV de sklearn

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf_good = GridSearchCV(KNeighborsClassifier(),param_grid={"n_neighbors":range(1,30)},scoring="accuracy")

# %% [markdown]
# Entrenamos de nuevo el modelo, buscando el mejor clasificador (Nota** el proceso consume tiempo y recursos)

# %%
clf_good.fit(X_train,y_train)
print(clf_good.best_params_)
# Out:
# {'n_neighbors': 28}

# %%
#np.mean(cross_val_score(clf_good,X,y,cv=10,scoring="accuracy"))

# %%
#accuracy_score(clf_good.predict(X_test),y_test)

# %% [markdown]
# ### Knn-Neightbors: approach 2

# %%
df_model_fil.columns
# Out:
# Index(['target', 'Sexo', 'AnioCumplidos', 'TamanioMuniResi',
#        'total_anios_Expo_Id', 'Total_Kg_expo', 'Distance',
#        'Cont_Dióxido de carbono (CO2)', 'Cont_Partículas (PM10)'],
#       dtype='object')

# %% [markdown]
# ### Pre-processing: Feature Scaling

# %% [markdown]
# Procedemos a estandarizar variables numéricas, para ello utilizamos dos métodos diferentes, para comparar resultados

# %% [markdown]
# #### Standardization Vs Min-Max scaling

# %%
from sklearn import preprocessing

#Columns of interest for preprocessing
columnas = ['AnioCumplidos', 'TamanioMuniResi', 'total_anios_Expo_Id', 'Total_Kg_expo','Distance']

#Estandarización sólo para ejemplo de comparación
std_scale  = preprocessing.StandardScaler().fit(df_model_fil) 
df_std = std_scale.transform(df_model_fil) #Solo para utilizar el array en la prueba siguiente.

#MinMax scale sólo para ejemplo de comparación
minmax_scale = preprocessing.MinMaxScaler().fit(df_model_fil)
df_minmax = minmax_scale.transform(df_model_fil)

#Escalamos las columnas de interes.
df_model_fil[columnas] = preprocessing.StandardScaler().fit_transform(df_model_fil[columnas]) #Solo columnas de interés escaladas
df_model_std = df_model_fil #asignamos para cambiar nombre

# %%
df_model_std.head()
# Out:
#    target  Sexo  AnioCumplidos  TamanioMuniResi  total_anios_Expo_Id  \
# 0       1     1      -0.979792        -0.701283             1.237907
# 1       0     0       0.420983        -0.701283             1.237907
# 2       0     0      -0.463717        -0.701283             1.237907
# 3       0     0      -1.938217        -0.701283             1.237907
# 4       0     0       1.084508        -0.701283             1.237907
#
#    Total_Kg_expo  Distance  Cont_Dióxido de carbono (CO2)  \
# 0       3.686373  0.121769                              1
# 1       3.686373  0.121769                              1
# 2       3.686373  0.121769                              1
# 3       3.686373  0.121769                              1
# 4       3.686373  0.121769                              1
#
#    Cont_Partículas (PM10)
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# Calculamos el estadísico Z-score para cada valor, en relación a la media y la desviación estándar

# %%
from scipy import stats
df= np.array(df_std)
zscore_df = stats.zscore(df, axis=1)
#print (zscore_df)

# %% [markdown]
# Observamos los valores, para poder comparar

# %%
print('Mean after standardization:\nTotal_Kg_expo={:.2f},total_anios_Expo_Id={:.2f}'
      .format(df_std[:,4].mean(), df_std[:,2].mean()))
print('\nStandard deviation after standardization:\nTotal_Kg_expol={:.2f},total_anios_Expo_Id={:.2f}'
      .format(df_std[:,4].std(), df_std[:,3].std()))
# Out:
# Mean after standardization:
# Total_Kg_expo=0.00,total_anios_Expo_Id=0.00
#
# Standard deviation after standardization:
# Total_Kg_expol=1.00,total_anios_Expo_Id=1.00

# %%
print('Min-value after min-max scaling:\nTotal_Kg_expo={:.2f}, total_anios_Expo_Id={:.2f}'
      .format(df_minmax[:,4].min(), df_minmax[:,3].min()))
print('\nMax-value after min-max scaling:\nTotal_Kg_expol={:.2f}, total_anios_Expo_Id={:.2f}'
      .format(df_minmax[:,4].max(), df_minmax[:,3].max()))
# Out:
# Min-value after min-max scaling:
# Total_Kg_expo=0.00, total_anios_Expo_Id=0.00
#
# Max-value after min-max scaling:
# Total_Kg_expol=1.00, total_anios_Expo_Id=1.00

# %% [markdown]
# #### Vamos a aplicar el escalado estandar al dataframe completo dividiendo un set de entrenamiento y test

# %% [markdown]
# Volvemos a dividir el dataframe escalado

# %%
from sklearn.model_selection import train_test_split

X_ = df_model_std.values[:,1:] #Resto de columnas escaladas
y_ = df_model_std.values[:,0] #columna target

X_train, X_test, y_train, y_test = train_test_split(X_, y_,
    test_size=0.30, random_state=12345)

# %% [markdown]
# Obtenemos el clasificador, le pasamos 28 como knn ya que es el valor que obtuvimos anteriormente y despues de correr el modelo varias veces es el más óptimo

# %%
clf2 = KNeighborsClassifier(n_neighbors=28)

# %% [markdown]
# Entrenamos el modelo con el set estandarizado

# %%
clf2.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=28, p=2,
#            weights='uniform')

# %% [markdown]
# clf.fit(X_train,y_train)

# %% [markdown]
# Hacemos la predicción

# %%
prediccion_test2 = clf2.predict(X_test)
prediccion_test2
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# #### Calculamos de nuevo la matriz de Confusión

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, prediccion_test2)
print (cm)
# Out:
# [[21484    49]
#  [ 4106    19]]

# %%
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.winter)
classNames = ['Negative','Positive']
plt.title('Deaths Scaled Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

# %% [markdown]
# Calculamos el Accuracy score

# %%
from sklearn.metrics import accuracy_score
accuracy_score(clf2.predict(X_test),y_test)
# Out:
# 0.838062202821732

# %% [markdown]
# Realizamos la validación cruzada del modelo

# %%
# Crossval score
from sklearn.model_selection import cross_val_score
cross_val_score(clf2,X,y,cv=10,scoring="accuracy")
# Out:
# array([0.83841927, 0.8328072 , 0.83830235, 0.83818543, 0.82555828,
#        0.83269028, 0.83863424, 0.78893826, 0.79922825, 0.83816651])

# %% [markdown]
# Obtenemos la media de los valores anteriores

# %%
np.mean(cross_val_score(clf2,X,y,cv=10,scoring="accuracy"))
# Out:
# 0.8270930079183809

# %% [markdown]
# En conclusión se puede decir que el escalado de nuestras variables numéricas ha mejorado nuestro "Accuracy" del modelo
