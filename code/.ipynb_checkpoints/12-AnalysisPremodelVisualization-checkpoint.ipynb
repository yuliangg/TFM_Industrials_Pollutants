# %% [markdown]
# # Analysis pre-model Visualization

# %%
import pandas as pd
import numpy as np
import csv

#Data visualization
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# Se lee el CSV procedente del script de generación del model final, el cual está agrupado por Contaminante e Id único (defunción).

# %%
df_model = pd.read_csv('../data/csv/model_csv/df_model_geom.csv', sep=';', encoding= 'utf-8',  compression='gzip', index_col=False)

# %%
df_model.shape
# Out:
# (85526, 29)

# %%
pd.options.display.max_columns = None

# %%
df_model['Id'].nunique()
# Out:
# 52806

# %% [markdown]
# Vemos todas las variables y su tipo

# %%
df_model.dtypes
# Out:
# Unnamed: 0                  int64
# Id                          int64
# ProvinciaReside             int64
# MunicipioReside             int64
# Sexo                        int64
# AnioCumplidos               int64
# TamanioMuniResi             int64
# CausaMortaReduc             int64
# NivelEstudios               int64
# Poblacion                  object
# Provincia                  object
# Comunidad                  object
# Latitud                   float64
# Longitud                  float64
# Habitantes                  int64
# Hombres                     int64
# Mujeres                     int64
# CodigoPRTR                  int64
# LongitudE                 float64
# LatitudE                  float64
# Contaminante               object
# total_anios_Expo_Id         int64
# Total_Kg_expo             float64
# COD_3                      object
# Descripcion_Cod_3          object
# target                      int64
# geometry_death             object
# geometry_focalEmission     object
# Distance                    int64
# dtype: object

# %%
df_model.drop(['Unnamed: 0'], axis=1, inplace=True) #Borramos columnas innecesarias

# %% [markdown]
# Comprobamos si alguna columna tiene valores NA para depurarlos

# %%
df_model.isnull().any()
# Out:
# Id                        False
# ProvinciaReside           False
# MunicipioReside           False
# Sexo                      False
# AnioCumplidos             False
# TamanioMuniResi           False
# CausaMortaReduc           False
# NivelEstudios             False
# Poblacion                 False
# Provincia                 False
# Comunidad                 False
# Latitud                   False
# Longitud                  False
# Habitantes                False
# Hombres                   False
# Mujeres                   False
# CodigoPRTR                False
# LongitudE                 False
# LatitudE                  False
# Contaminante              False
# total_anios_Expo_Id       False
# Total_Kg_expo             False
# COD_3                     False
# Descripcion_Cod_3         False
# target                    False
# geometry_death            False
# geometry_focalEmission    False
# Distance                  False
# dtype: bool

# %% [markdown]
# #### Visualizamos las longitudes y latitudes como scatter

# %%
sns.jointplot(data=df_model, x='Longitud', y='Latitud');

# %% [markdown]
# Vemos la correlación de las variables numéricas

# %%
df_model.corr()
# Out:
#                            Id  ProvinciaReside  MunicipioReside      Sexo  \
# Id                   1.000000         0.030725         0.206728  0.000383
# ProvinciaReside      0.030725         1.000000         0.216063 -0.007930
# MunicipioReside      0.206728         0.216063         1.000000 -0.008969
# Sexo                 0.000383        -0.007930        -0.008969  1.000000
# AnioCumplidos        0.026404        -0.018454        -0.005241  0.092332
# TamanioMuniResi      0.057509         0.006033        -0.126266  0.035713
# CausaMortaReduc     -0.008348        -0.037466        -0.001863  0.063787
# NivelEstudios        0.013468         0.000198        -0.004172 -0.024359
# Latitud              0.170906        -0.066377         0.131970  0.001642
# Longitud             0.480627        -0.376104         0.247420 -0.007110
# target                    0.013743 -0.002907  0.000733    0.002962  0.003151
# Distance                 -0.000204  0.145412  0.098257   -0.191848 -0.193358
#
#                       Mujeres  CodigoPRTR  LongitudE  LatitudE  \
# Id                   0.426083    0.244957   0.481733  0.171167
# ProvinciaReside     -0.229415    0.128335  -0.376236 -0.066528
# MunicipioReside     -0.121575    0.009079   0.247231  0.131332
# Sexo                 0.029806    0.011027  -0.007069  0.001633
# AnioCumplidos        0.048389    0.016653   0.039613  0.059541
# TamanioMuniResi      0.521762    0.157804  -0.056138 -0.115065
# CausaMortaReduc      0.018237   -0.007611   0.004805 -0.017001
# NivelEstudios        0.024763    0.023190   0.008414 -0.012998
# Latitud              0.071708    0.162007   0.554075  0.999966
# Longitud             0.355330    0.222259   0.999969  0.555680
# Habitantes           0.999948    0.404509   0.358555  0.071007
# Hombres              0.999770    0.405617   0.360090  0.067996
# Mujeres              1.000000    0.403460   0.357123  0.073731
# CodigoPRTR           0.403460    1.000000   0.222890  0.162247
# LongitudE            0.357123    0.222890   1.000000  0.554480
# LatitudE             0.073731    0.162247   0.554480  1.000000
# total_anios_Expo_Id  0.556223    0.225687   0.127707  0.137045
# Total_Kg_expo        0.202235    0.178102   0.020122  0.016385
# target               0.002790    0.005330   0.000760 -0.002950
# Distance            -0.190456   -0.051760   0.098668  0.144985
#
#                      total_anios_Expo_Id  Total_Kg_expo    target  Distance
# Id                              0.284273       0.057617  0.014602 -0.001108
# ProvinciaReside                -0.112325      -0.106982  0.020994 -0.069631
# MunicipioReside                -0.145576      -0.150395  0.006096  0.083088
# Sexo                            0.011167      -0.000627 -0.170597 -0.006326
# AnioCumplidos                   0.036974       0.008258 -0.184499 -0.003583
# TamanioMuniResi                 0.306646       0.131631  0.010146 -0.158732
# CausaMortaReduc                 0.008567       0.001415 -0.289014 -0.003430
# NivelEstudios                   0.005832      -0.002285  0.013743 -0.000204
# Latitud                         0.136661       0.015229 -0.002907  0.145412
# Longitud                        0.126995       0.019414  0.000733  0.098257
# Habitantes                      0.554364       0.201195  0.002962 -0.191848
# Hombres                         0.552250       0.200025  0.003151 -0.193358
# Mujeres                         0.556223       0.202235  0.002790 -0.190456
# CodigoPRTR                      0.225687       0.178102  0.005330 -0.051760
# LongitudE                       0.127707       0.020122  0.000760  0.098668
# LatitudE                        0.137045       0.016385 -0.002950  0.144985
# total_anios_Expo_Id             1.000000       0.263919  0.001302 -0.011422
# Total_Kg_expo                   0.263919       1.000000  0.003135  0.160868
# target                          0.001302       0.003135  1.000000 -0.004064
# Distance                       -0.011422       0.160868 -0.004064  1.000000

# %% [markdown]
# Debido a que el dataframe es muy pesado, vamos a plotear y explorar los datos para una Comunidad concreta con valores de Distancia al foco contaminante por debajo de un umbral.

# %%
df_fil_Comu = df_model[ (df_model['Comunidad'] == 'Andalucía') &  (df_model['Distance'] <= 8000) ]

# %% [markdown]
# Ploteamos por la Comunidad en concreto mediante un jointplot y observamos concentraciones en determinadas zonas según la ubicación

# %%
sns.jointplot(x="Longitud", y="Latitud", data=df_fil_Comu, kind='kde');

# %% [markdown]
# Vamos a hacer un pairplot con determinadas variables

# %%
col = ['Contaminante', 'Latitud', 'Longitud', 'target','total_anios_Expo_Id']
df_fil_Comu1 = df_fil_Comu [col]

# %%
sns.pairplot(df_fil_Comu1, hue='Contaminante', size=2.5);

# %% [markdown]
# En el gráfico anterior observamos que para determinadas Latitudes y Longitudes hay agrupaciones de ciertos tipos de enfermedades, igualmente la distribución geográfica parece tener cierta relación con el tipo de Contaminante emitido

# %% [markdown]
# Ploteamos el tipo contaminante (var convertida a numérica) y el tipo de enfermedad causante defunción, estas no tienen relación directa pero se observan las modas en cada variable.

# %%
sns.distplot(df_fil_Comu['Sexo'])
sns.distplot(df_fil_Comu['total_anios_Expo_Id']);

# %% [markdown]
# Vemos la relación gráfica entre las variables poblaciones de Años cumplidos fecha defun, Nivel estudios y Sexo

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot("NivelEstudios", "AnioCumplidos", "Sexo", data=df_fil_Comu, kind="box")
    g.set_axis_labels("NivelEstudios", "AnioCumplidos");

# %% [markdown]
# Ploteamos en un HeatMap el Contaminante y años exposición de cada persona y contamos las defunciones

# %%
mean_Id = df_model.groupby(['Contaminante', 'total_anios_Expo_Id'])['Id'].count()

# %%
sns.heatmap(mean_Id[:-1][1:].unstack(), linewidths=.1);

# %% [markdown]
# Realizamos un clusterMap para ver las correlaciones entre variables

# %%
sns.clustermap(df_fil_Comu.corr());

# %% [markdown]
# Pudiera haber algo de relación entre el tamaño del municipio de residencia y el total de años de exposición al Contaminante

# %%
lot = df_model['Sexo'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='Fallecimiento totales por Sexo, 2015. 1:hombres, 6:mujeres')

# %%
plot = df_model.groupby('Comunidad')['Sexo'].value_counts().plot(kind='bar',
                                            title='Fallecimiento por provincia y sexo')

# %% [markdown]
# ### Visualización con Folium

# %%
#pip install folium
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
df_fil_Provincia= df_model[ (df_model['Provincia'] == 'Sevilla') &  (df_model['Distance'] <= 100) ]
df_fil_Provincia.shape
# Out:
# (0, 28)

# %%
sevilla_coordinates = [37.3914105, -5.9591776]

# %%
colors = {1 : 'red', 6: 'blue'}


map_osm = folium.Map(location=sevilla_coordinates, zoom_start=11)

for _, row in df_fil_Provincia.iterrows():
    folium.CircleMarker(location=[row["Latitud"], row["Longitud"]], radius=5, fill_color=colors[row['Sexo']]).add_to(map_osm)

    folium.Marker(location=[row["LatitudE"], row["LongitudE"]], icon=DivIcon(icon_size=(150,36), icon_anchor=(0,0),
        html='<div style="font-size: 16pt; color : {}">{}</div>'.format(colors[row['CodigoPRTR']], 
                                                                        row['CodigoPRTR']))).add_to(map_osm)


map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
